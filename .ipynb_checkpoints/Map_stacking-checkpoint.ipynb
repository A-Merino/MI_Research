# %%
import torch
from torch import utils
import numpy as np
import torchvision as tv
from torchvision.models import vgg16 as VGG
from torchvision.datasets import Imagenette
import torchvision.transforms as tfs
import torch.nn as nn
from torchsummary import summary
from sklearn.model_selection import train_test_split
from pathlib import Path
import pickle
import os
import glob
from PIL import Image
import matplotlib.pyplot as plt

# %%
import importlib
import extract
from extract import VGG16FeatureExtractor as features
import fmppmi as ppmi
importlib.reload(extract)
importlib.reload(ppmi)
# Out:
# <module 'fmppmi' from 'C:\\Users\\Alex Merino\\Documents\\research_MI\\fmppmi.py'>

# %%
def get_maps(path):
    image = None

    # UNPICKLE
    with open (path, 'rb') as f:
        image = pickle.load(f)

    return image

# %%
folder = glob.glob("./feature_maps/test1/*")

inputs = []
for image in folder:
    inputs.append(get_maps(image))
# Out:
# ['./feature_maps/test1\\ILSVRC2012_val_00000293.pkl', './feature_maps/test1\\ILSVRC2012_val_00002138.pkl', './feature_maps/test1\\ILSVRC2012_val_00003014.pkl', './feature_maps/test1\\ILSVRC2012_val_00006697.pkl', './feature_maps/test1\\ILSVRC2012_val_00007197.pkl', './feature_maps/test1\\ILSVRC2012_val_00009346.pkl', './feature_maps/test1\\ILSVRC2012_val_00009379.pkl', './feature_maps/test1\\ILSVRC2012_val_00009396.pkl', './feature_maps/test1\\ILSVRC2012_val_00010306.pkl', './feature_maps/test1\\ILSVRC2012_val_00011233.pkl', './feature_maps/test1\\ILSVRC2012_val_00011993.pkl']

# %%
for i in range(len(inputs), 0, -1):
    for fm in inputs:
        print(fm[i].size())
# Out:
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
# torch.Size([1, 64, 224, 224])
